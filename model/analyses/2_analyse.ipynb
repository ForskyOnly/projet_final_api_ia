# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/utilisateur/Documents/dev/devia/projet_final_api_ia/database/data/cleaned_data.csv")

# %%
df
# Out:
#         CarName      carbody drivewheel  wheelbase  carlength  carwidth  \
# 0    alfa-romeo  convertible        rwd     225.04     428.75    162.81
# 1    alfa-romeo  convertible        rwd     225.04     428.75    162.81
# 2    alfa-romeo    hatchback        rwd     240.03     434.85    166.37
# 3          audi        sedan        fwd     253.49     448.56    168.15
# 4          audi        sedan        4wd     252.48     448.56    168.66
# ..          ...          ...        ...        ...        ...       ...
# 200       volvo        sedan        rwd     277.11     479.55    175.01
# 201       volvo        sedan        rwd     277.11     479.55    174.75
# 202       volvo        sedan        rwd     277.11     479.55    175.01
# 203       volvo        sedan        rwd     277.11     479.55    175.01
# 204       volvo        sedan        rwd     277.11     479.55    175.01
#
#      curbweight enginetype  cylindernumber  enginesize fuelsystem  boreratio  \
# ...

# %%
cor = df.corr()
print(cor['price'].sort_values(ascending=False))
# Out:
# price             1.000000
# enginesize        0.874145
# curbweight        0.835305
# horsepower        0.808139
# carwidth          0.759250
# cylindernumber    0.718305
# carlength         0.682922
# wheelbase         0.577796
# boreratio         0.553173
# citympg          -0.685751
# highwaympg       -0.697599
# Name: price, dtype: float64
# /tmp/ipykernel_211725/129322031.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = df.corr()

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(cor, cmap='YlGnBu', annot=True)
plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
sns.regplot(y='curbweight', x='price', data=df, ax=axes[0])
sns.regplot(y='horsepower', x='price', data=df, ax=axes[1])
sns.regplot(y='enginesize', x='price', data=df, ax=axes[2])
sns.regplot(y='boreratio', x='price', data=df, ax=axes[3])
# Out:
# <AxesSubplot: xlabel='price', ylabel='boreratio'>

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

sns.regplot(y='wheelbase', x='price', data=df, ax=axes[0])
sns.regplot(y='carlength', x='price', data=df, ax=axes[1])
sns.regplot(y='carwidth', x='price', data=df, ax=axes[2])
sns.scatterplot(y='fuelsystem', x='price', data=df, ax=axes[3])
# Out:
# <AxesSubplot: xlabel='price', ylabel='fuelsystem'>

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

sns.scatterplot(y='CarName', x='price', data=df, ax=axes[0])
sns.scatterplot(y='carbody', x='price', data=df, ax=axes[1])
sns.scatterplot(y='drivewheel', x='price', data=df, ax=axes[2])
sns.scatterplot(y='enginetype', x='price', data=df, ax=axes[3])
# Out:
# <AxesSubplot: xlabel='price', ylabel='enginetype'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

sns.scatterplot(y='cylindernumber', x='price', data=df, ax=axes[0])
sns.regplot(y='citympg', x='price', data=df, ax=axes[1])
sns.regplot(y='highwaympg', x='price', data=df, ax=axes[2])
# Out:
# <AxesSubplot: xlabel='price', ylabel='highwaympg'>

# %%
df.to_csv("/home/utilisateur/Documents/dev/devia/projet_final_api_ia/database/data/cleaned_data.csv", index=False)
